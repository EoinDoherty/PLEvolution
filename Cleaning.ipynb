# %% [markdown]
# ## Data Cleaning
# Cleaning the raw data taken from the wikipedia scraper.

# %%
import numpy as np

# %%
with open("Data/metadata_final.csv") as f:
    raw_lines = f.readlines()
    processed = [line.split("\t") for line in raw_lines]
    node_info = dict([(int(line[0]), eval(line[1])) for line in processed])

# %%
for num in node_info:
    print(node_info[num]["title"])
# Out:
# 1c:enterprise programming language
# a#
# a-0 system
# a+
# a++
# abap/4
# abc
# abc algol
# acc (programming language)
# accent (programming language)
# distributed application specification language
# action!
# actionscript
# actor (programming language)
# ada
# adenine (programming language)
# agda (theorem prover)
# agilent vee
# agora (programming language)
# aimms
# aldor
# alef
# alf
# algol 58
# algol 60
# algol 68
# algol w
# alice
# alma-0
# ambienttalk
# amiga e
# amos
# ampl
# angelscript
# apex (programming language)
# apl
# app inventor for android (programming language)
# applescript
# apt (programming language)
# arc
# arexx
# argus (programming language)
# assembly language
# autohotkey
# autolisp
# averest
# awk
# axum
# active server pages (asp)
# b
# babbage
# ballerina
# bash
# basic
# bc
# bcpl
# beanshell
# batch file
# bertrand (programming language)
# beta
# bliss (programming language)
# blockly
# bloop and floop
# boo
# boomerang
# bourne shell
# c
# c--
# c++
# c*
# c#
# c/al
# caché objectscript
# c shell
# caml
# cayenne (programming language)
# cduce
# cecil (programming language)
# cesil
# céu (programming language)
# ceylon
# cfengine
# cg (programming language)
# ch c/c++ interpreter
# chapel
# charity
# charm (language)
# chill
# chip-8
# pp, chomski virtual machine
# chuck
# cilk
# citrine
# as/400 control language
# claire
# clarion
# clean
# clipper
# clips (programming language)
# clist
# clojure
# clu
# cms-2
# cobol
# cobolscript
# cobra
# coffeescript
# coldfusion
# comal
# combined programming language
# comit
# common intermediate language
# common lisp
# compass
# component pascal
# constraint handling rules
# comtran
# cool
# coq (software)
# coral 66
# corvision
# cowsel
# cpl
# cryptol
# crystal
# csound
# communicating sequential processes
# cuneiform
# curl
# curry
# cybil (programming language)
# cyclone
# cython
# d programming language
# datapoint's advanced systems language
# dart
# darwin
# dataflex
# datalog
# datatrieve
# dbase
# dc (computer program)
# digital command language
# dink smallwood
# dibol
# dog (programming language)
# draco
# drakon
# dylan
# dynamo (programming language)
# data analysis expressions
# e
# ease
# pl/i
# easytrieve
# ec
# ecmascript
# edinburgh imp
# egl (programming language)
# eiffel
# elan
# elixir
# elm
# emacs lisp
# emerald
# epigram
# easy programming language
# eltron programming language
# erlang
# es (unix shell)
# escher
# executive systems problem oriented language
# esterel
# etoys
# euclid
# euler
# euphoria
# euslisp robot programming language
# cms exec
# exec 2
# executable uml
# ezhil
# f language
# f#
# f*
# factor
# fantom
# faust
# ffp (programming language)
# fjölnir
# fl
# flavors (programming language)
# flex (language)
# flow-matic
# focal
# focus
# foil (programming language)
# formac (programming language)
# formula language
# forth
# fortran
# fortress
# fp
# franz lisp
# f-script
# game maker language
# gamemonkey script
# gams
# gap computer algebra system
# g-code
# gdscript
# genie
# geometric description language
# george (programming language)
# glsl
# gnu e
# go
# go!
# game oriented assembly lisp
# gödel
# golo
# mad
# apps script
# gosu
# ibm 1620
# gpss
# dxc technology
# grass (programming language)
# grasshopper
# groovy (programming language)
# hack
# haggis
# hal/s
# halide
# hamilton c shell
# harbour (software)
# hartmann pipeline
# haskell
# haxe
# hermes (programming language)
# high level assembly (hla)
# high level shader language
# hollywood
# templeos
# hop
# hopscotch (programming language)
# hope (programming language)
# hugo (programming language)
# hume (language)
# hypertalk
# io
# icon
# ibm basic assembly language
# ibm hascript
# ibm informix-4gl
# rpgreport program generator
# irineu
# idl (interactive data language)
# idris
# inform (programming language)
# j
# visual j#
# visual j++
# jade (programming language)
# jal (compiler)
# janus
# janus
# jass
# java
# javafx
# javascript
# job control language
# jean
# join java
# joss
# joule
# jovial
# joy
# jscript
# jscript .net
# julia
# jython
# k
# kaleidoscope (programming language)
# karel the robot
# intellicorp (software)
# kixtart
# klerer-may system
# knowledge interchange format
# kojo (programming language)
# kotlin
# krc
# krl
# kuka robot language
# krypton
# korn shell
# kodu
# kivy
# labview
# ladder logic
# lansa (development environment)
# lasso
# lava (programming language)
# lc-3
# legoscript
# little implementation language
# lilypond
# limbo
# limnor
# linc 4gl
# lingo (programming language)
# linq
# lis (programming language)
# language for instruction set architecture
# lisp
# lite-c
# lithe (programming language)
# little b
# ethereum
# logo
# logtalk
# lotusscript
# lpc
# lse (programming language)
# linden scripting language
# livecode
# livescript
# lua
# lucid
# lustre (programming language)
# lyapas
# lynx (programming language)
# m2001
# m4
# m sharp (programming language)
# machine code
# magik (programming language)
# magma computer algebra system
# maude system
# máni
# maple
# mapper
# mark iv (software)
# mary
# microsoft macro assembler
# math-matic
# mathematica
# matlab
# maxima
# max
# autodesk 3ds max
# maya embedded language
# mdl
# mercury
# mesa[1]
# metafont
# mheg-5
# microassembler
# microscript (programming language)
# miis (programming language)
# milk (programming language)
# mimic
# mirah
# miranda
# miva script
# ml
# model 204
# modelica
# modula
# modula-2
# modula-3
# mohol programming languages
# moo
# mortran
# mouse (programming language)
# mpd (programming language)
# mathcad
# mirc scripting language
# mumps
# mupad
# mystic bbs
# netwide assembler
# napier88
# neko (programming language)
# nemerle
# nesl
# net.data
# netlogo
# netrexx
# newlisp
# newp
# newspeak
# newtonscript
# nial
# nice (programming language)
# nickle
# nim
# nord programming language
# not exactly c
# not quite c
# nullsoft scriptable install system
# nu
# nwscript
# nxt-g
# o:xml
# oak (programming language)
# oberon
# obj2
# object lisp
# objectlogo
# object rexx
# object pascal
# objective-c
# objective-j
# obliq
# ocaml
# occam
# occam-π
# gnu octave
# omnimark
# onyx (programming language)
# opa
# opal (programming language)
# opencl api
# openedge advanced business language (abl)
# open programming language (opl)
# openvera
# ops5
# optimj
# orc
# orca/modula-2
# oriel
# orwell
# oxygene
# oz
# p
# p4
# p′′
# parasail
# pari/gp
# pascal
# pascal script
# pcastl
# programming language for computable functions
# pearl (programming language)
# peoplecode
# perl
# perl data language (pdl)
# perl 6
# pharo
# php
# pico
# picolisp
# pict
# pig (programming tool)
# pike
# pilot
# pizza
# pl-11
# pl/0
# programming language for business
# pl/c
# pl/m
# pl/p
# pl/sql
# pl360
# planc
# plankalkül
# planner
# plex
# plexil
# plus
# pop-11
# pop-2
# postscript
# pov-ray
# powerhouse (programming language)
# appeon powerbuilder
# powershell
# polymorphic programming language
# processing
# processing.js
# prograph
# proiv
# prolog
# promal
# promela
# prose modeling language
# protel
# providex
# pro*c
# pure
# pure data
# python
# q
# q#
# قلب
# qtscript
# quakec
# quantum programming
# qbasic
# r
# r++
# racket
# rapid
# rapira
# ratfiv
# ratfor
# rc
# reason
# rebol
# red
# core war
# refal
# rexx
# rlab
# roop (programming language)
# rpl
# robot battle
# rtl/2
# ruby
# runescript
# rust
# s
# s2
# s3
# s-lang (programming language)
# s-plus
# sa-c (programming language)
# sabretalk
# sail (programming language)
# sam76
# sas system
# sasl
# sather
# sawzall (programming language)
# scala
# scheme
# scilab
# scratch
# script.net
# sed
# seed7
# self
# sensetalk
# sequencel
# setl
# superbase database
# signal (programming language)
# simple
# simscript
# simula
# simulink
# singularity project
# sisal
# slip (programming language)
# small
# smalltalk
# standard ml
# strongtalk
# snap! (byob[note 1])
# snobol
# snowball programming language
# secure operations language
# solidity
# sophaeros
# spark
# speakeasy
# speedcoding
# parallax propeller
# sp/k
# ibm 1401 symbolic programming system
# sql
# sqr
# squeak
# squirrel
# sr (programming language)
# s/sl programming language
# starlogo
# strand (programming language)
# stata
# stateflow
# subtext (programming language)
# supercollider
# supertalk
# swift
# swift
# sympl
# systemverilog
# t
# tacl
# tacpol (programming language)
# tads
# transaction application language
# tcl
# tea
# text editor and corrector
# telcomp
# ubercode
# ucsd pascal/p-system
# umple
# unicon
# uniface
# unity (programming language)
# unix shell
# unrealscript
# vala
# verilog
# vhdl
# vim
# visual basic
# visual basic .net
# visual dataflex
# visual dialogscript
# visual fortran
# visual foxpro
# visual j
# visual objects
# visual prolog
# vsxu
# watfiv (programming language)
# webassembly
# webdna
# whiley
# winbatch
# wolfram language
# wyvern (programming language)
# x++
# x10
# xbase
# xbase++
# xbl
# xc programming language
# xharbour
# xl
# xojo
# xotcl
# xod
# xpath
# xpl
# xpl0
# xquery
# xsb
# xsharp
# xsl transformations
# xtend
# yorick
# yql (programming language)
# yoix
# yahoo! user interface library
# z notation
# zebra programming language
# zeno (programming language)
# zetalisp
# zopl
# z shell
# zpl
# z++
# wikipedia:citation needed
# pl/pgsql
# sql/psm
# a♯
# newsqueak
# algol-like
# fortran
# kornshell
# steelman language requirements
# ada programming language
# algol y
# ecmascript harmony
# actor-based concurrent language
# stos basic
# coopr
# mathematical notation
# natural language programming
# korn shell
# javascript (programming language)
# autoit
# xslt
# category:c programming language family
# c shell
# c99
# dataparallel-c
# ansi c
# *lisp (starlisp)
# typescript
# cω
# high performance fortran
# cray mta
# cray xmt
# pl/1
# awk
# openmp
# hy
# lfe
# aimaco
# fact computer language
# yaml
# eulisp
# islisp
# autolisp
# moose (perl)
# skill
# subl
# lisp machine lisp
# maclisp
# interlisp
# oberon-2
# algol
# inform
# html(hypertext markup language)
# minid
# qore
# foxpro
# vp-info[1]
# windows powershell
# common lisp object system
# redux
# vue.js
# agda
# alf (theorem prover)
# akka
# reia (programming language)
# simple theory of types
# croquet
# hypercard
# starlogo
# agentsheets
# concurrent euclid (programming language)
# turing
# fortran 95
# dafny (programming language)
# arith-matic
# basic-plus
# burroughs large systems
# pact i
# allegro common lisp
# bluespec, inc.
# c++11
# concepts (c++)
# language integrated query
# isabelle theorem prover
# generics in java
# omega
# purescript
# raku
# gofer (programming language)
# id (programming language)
# iswim
# ioke
# actor model middle history
# unicon programming language
# ibm rpg ii
# ibm 709/90 9pac
# fargo (programming language)
# numpy
# gambas
# haxe (programming language)
# atscript
# qml
# cal (programming language)
# logic programming
# actor model
# semi-automatic ground environment
# miranda programming language
# stackless python
# clips
# rebol
# information processing language (ipl)
# kturtle
# puredata
# interactive fiction
# cedar (programming language)
# sasl programming language
# fortran 90
# zonnon
# algol-w
# modula-2+
# algol programming language
# lisp programming language
# muf (programming language)
# profile scripting language
# nineteen eighty-four: a novel
# io programming language
# dylan programming language
# apl programming language
# active oberon
# rexx
# tom
# ats
# brainfuck
# oberon-2 (programming language)
# structured text
# awk (programming language)
# generic java
# scala programming language
# superplan
# heinz rutishauser
# begriffsschrift
# portable document format
# interpress
# as/400 control language
# tk
# chef
# puppet (software)
# functional programming
# dataflow
# diagram
# kl0
# kl1
# business basic
# groovy
# xlispstat
# inferno
# reverse polish notation
# algol 68
# scratchjr
# agentcubes
# ed
# setl2
# isetl
# list of object-oriented programming languages
# simscript
# sac
# imp (programming language)
# sketchpad
# arpanet
# burroughs b5000
# cell (biology)
# ml programming language
# java hotspot virtual machine
# contextual query language
# sparql
# java persistence query language
# java object oriented querying
# n1ql
# unified modeling language
# icon programming language
# basic4ppc
# nsb/appstudio
# microsoft small basic
# opengl
# asm.js
# google native client
# symbolic manipulation program
# otcl
# xml schema (w3c)
# xforms
# xpointer
# dsssl
# joins (concurrency library)
# polyphonic c sharp
# kawa
# clojure (programming language)
# hy (programming language)
# interlisp
# lelisp
# objvlisp
# oaklisp
# le lisp
# d language
# microsoft basic
# dartmouth basic
# tymshare super basic
# macsyma
# qt (framework)
# xaml
# json
# dependent ml
# esoteric programming language
# hibernate (java)
# qbasic
# t programming language
# openlisp
# list of basic dialects
# freebasic
# qb64
# quickbasic
# gw-basic
# qbasic
# quickbasic
# msx basic
# ibm cassette basic
# ibm disk basic
# ibm basica
# vilnius basic

# %%
edges = set()

for num in node_info:
    lang = node_info[num]
    
    for key in lang['influenced']:
        edges.add((num, key))
    
    for key in lang['influenced by']:
        edges.add((key, num))

# %%
with open("Data/edges.txt", "w") as f:
    for parent, child in edges:
        f.write(f"{parent} {child}\n")

# %% [markdown]
# ## Node info file

# %%
import re

# %%
pat = re.compile(".*(\d{4}).*")
pat.match("December 1234").group(1)
# Out:
# '1234'

# %%
year_finder = re.compile(".*(\d{4}).*")

for key in node_info:
    year = node_info[key]["year"]
    
    if type(year) == str:
        new_year = year_finder.match(year)
        
        if new_year == None:
            print(f"Year not found in pattern: {year}")
        else:
            year = str(new_year.group(1))
    
    node_info[key]["clean year"] = year

# %%
with open("Data/node_info.tsv", "w") as f:
    for key in node_info:
        d = node_info[key]
        f.write(f"{key}\t{d['title']}\t{d['clean year']}\t{d['paradigm(s)']}\t{d['typing']}\n")

# %% [markdown]
# ### Joining multiple entries for the same programming language

# %%
with open("Data/node_info.tsv") as f:
    raw_lines = f.readlines()
    processed = [row.split('\t') for row in raw_lines]
    
    nodes = {}
    
    for line in processed:
        lang = {}
        lang_id = int(line[0])
        
        lang["name"] = line[1]
        lang["year"] = int(line[2])
        lang["paradigm"] = eval(line[3])
        lang["typing"] = eval(line[4])
        
        nodes[lang_id] = lang

# %%
repeats = set()
names = set()

for key in nodes:
    name = nodes[key]["name"]
    if name in names:
        repeats.add(name)
    else:
        names.add(name)

for name in repeats:
    for key in nodes:
        if nodes[key]["name"] == name:
            print(nodes[key])
    print()
# Out:
# {'name': 'interlisp', 'year': 1968, 'paradigm': [], 'typing': []}
# {'name': 'interlisp', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'qbasic', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'qbasic', 'year': 1991, 'paradigm': ['Procedural'], 'typing': []}
# {'name': 'qbasic', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'korn shell', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'korn shell', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'fortran', 'year': 1957, 'paradigm': ['multi-paradigm', 'structured', 'imperative', 'procedural', 'object-oriented', 'generic'], 'typing': ['strong', 'static', 'manifest']}
# {'name': 'fortran', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'rebol', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'rebol', 'year': 1997, 'paradigm': ['language oriented programming', 'data exchange', 'functional', 'prototype-based', 'imperative'], 'typing': ['dynamic', 'strong']}
#
# {'name': 'quickbasic', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'quickbasic', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'janus', 'year': 1990, 'paradigm': ['concurrent constraint logic'], 'typing': []}
# {'name': 'janus', 'year': 2007, 'paradigm': ['imperative', 'procedural', 'reversible'], 'typing': []}
#
# {'name': 'rexx', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'rexx', 'year': 1979, 'paradigm': ['multiparadigm', 'procedural', 'structured'], 'typing': []}
#
# {'name': 'autolisp', 'year': 1986, 'paradigm': [], 'typing': []}
# {'name': 'autolisp', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'c shell', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'c shell', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'algol 68', 'year': 1968, 'paradigm': ['multi-paradigm', 'concurrent', 'imperative'], 'typing': ['static', 'strong', 'safe', 'structural']}
# {'name': 'algol 68', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'starlogo', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'starlogo', 'year': 2001, 'paradigm': ['Multi-paradigm', 'educational', 'procedural', 'agent-based', 'simulation'], 'typing': ['duck', 'dynamic', 'strong']}
#
# {'name': 'simscript', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'simscript', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'awk', 'year': 1977, 'paradigm': ['Scripting', 'procedural', 'data-driven', '[1]'], 'typing': []}
# {'name': 'awk', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'as/400 control language', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'as/400 control language', 'year': 0, 'paradigm': ['imperative'], 'typing': []}

# %%
for key in nodes:
    if nodes[key]["name"] == 'swift':
        print(key)
# Out:
# 42946389
# 42946796

# %%
nodes[42946796]["name"] = "swift (parallel scripting language)"

# %%
double_entries = {}

for repeat in repeats:
    double_entries[repeat] = []

for key in nodes:
    lang = nodes[key]
    
    if lang["name"] in double_entries:
        entry = lang.copy()
        entry["id"] = key
        double_entries[lang["name"]].append(entry)

# %%
def merge_dicts(ds):
    acc = {'year': 0, 'paradigm':[], 'typing': []}
    
    d_scores = [0 for i in range(len(ds))]
    
    name = ds[0]['name']
    acc["name"] = name
    
    for i in range(len(ds)):
        if ds[i]["year"] != 0:
            acc["year"] = ds[i]['year']
            d_scores[i] += 1
        if len(ds[i]['paradigm']) != 0:
            acc["paradigm"] += ds[i]['paradigm']
            d_scores[i] += 1
        if len(ds[i]['typing']) != 0:
            acc["typing"] += ds[i]['typing']
            d_scores[i] += 1
    
    max_index = max(range(len(d_scores)), key=lambda x: d_scores[x])
    new_id = ds[max_index]['id']
    acc['id'] = new_id
    
    mapping = {}
    for d in ds:
        if d['id'] != new_id:
            mapping[d['id']] = new_id
    
    return acc, mapping

# %%
acc, mapping = merge_dicts(double_entries['fortran'])

# %%
acc
# Out:
# {'year': 1957,
#  'paradigm': ['multi-paradigm',
#   'structured',
#   'imperative',
#   'procedural',
#   'object-oriented',
#   'generic'],
#  'typing': ['strong', 'static', 'manifest'],
#  'name': 'fortran',
#  'id': 11168}

# %%
mapping
# Out:
# {10942: 11168}

# %%
mapping = {}

for name in double_entries:
    acc, new_ids = merge_dicts(double_entries[name])
    nodes[acc['id']] = acc
    
    for key in new_ids:
        nodes.pop(key)
        mapping[key] = new_ids[key]

# %% [markdown]
# Applying new mapping to the edge list

# %%
with open("Data/edges.txt") as f:
    raw_lines = f.readlines()
    processed_lines = [tuple(map(int, line.strip().split(" "))) for line in raw_lines]

# %%
mapped = [tuple(map(lambda x: mapping[x] if x in mapping else x, tup)) for tup in processed_lines]

# %%
with open("edges.txt", "w") as f:
    for i, j in mapped:
        f.write(f"{i} {j}\n")

# %% [markdown]
# Write new node info to file

# %%
nodes[60614939]
# Out:
# {'name': '1c:enterprise programming language',
#  'year': 0,
#  'paradigm': [],
#  'typing': []}

# %%
with open("Data/node_info.tsv", "w") as f:
    for key in nodes:
        d = nodes[key]
        f.write(f"{key}\t{d['name']}\t{d['year']}\t{d['paradigm']}\t{d['typing']}\n")

# %% [markdown]
# ### Getting rid of entries that aren't programming languages

# %%
with open("Data/node_info.tsv") as f:
    raw_lines = f.readlines()
    processed = [row.split('\t') for row in raw_lines]
    
    nodes = {}
    
    for line in processed:
        lang = {}
        lang_id = int(line[0])
        
        lang["name"] = line[1]
        lang["year"] = int(line[2])
        lang["paradigm"] = eval(line[3])
        lang["typing"] = eval(line[4])
        
        nodes[lang_id] = lang

# %%
a = list(nodes.keys())[:10]

# %%
remove_ls = []

for key in nodes:
    resp = input(nodes[key]["name"])
    if resp == "y":
        remove_ls.append(key)
# Out:
# 1c:enterprise programming language
# a#
# a-0 system
# a+
# a++
# abap/4
# abc
# abc algol
# acc (programming language)
# accent (programming language)
# distributed application specification language
# action!
# actionscript
# actor (programming language)
# ada
# adenine (programming language)
# agda (theorem prover)
# agilent vee
# agora (programming language)
# aimms
# aldor
# alef
# alf
# algol 58
# algol 60
# algol 68
# algol w
# alice
# alma-0
# ambienttalk
# amiga e
# amos
# ampl
# angelscript
# apex (programming language)
# apl
# app inventor for android (programming language)
# applescript
# apt (programming language)
# arc
# arexx
# argus (programming language)
# assembly language
# autohotkey
# autolisp
# averest
# awk
# axum
# active server pages (asp)
# b
# babbage
# ballerina
# bash
# basic
# bc
# bcpl
# beanshell
# batch file
# bertrand (programming language)
# beta
# bliss (programming language)
# blockly
# bloop and floop
# boo
# boomerang
# bourne shell
# c
# c--
# c++
# c*
# c#
# c/al
# caché objectscript
# c shell
# caml
# cayenne (programming language)
# cduce
# cecil (programming language)
# cesil
# céu (programming language)
# ceylon
# cfengine
# cg (programming language)
# ch c/c++ interpreter
# chapel
# charity
# charm (language)
# chill
# chip-8
# pp, chomski virtual machine
# chuck
# cilk
# citrine
# claire
# clarion
# clean
# clipper
# clips (programming language)
# clist
# clojure
# clu
# cms-2
# cobol
# cobolscript
# cobra
# coffeescript
# coldfusion
# comal
# combined programming language
# comit
# common intermediate language
# common lisp
# compass
# component pascal
# constraint handling rules
# comtran
# cool
# coq (software)
# coral 66
# corvision
# cowsel
# cpl
# cryptol
# crystal
# csound
# communicating sequential processes
# cuneiform
# curl
# curry
# cybil (programming language)
# cyclone
# cython
# d programming language
# datapoint's advanced systems language
# dart
# darwin
# dataflex
# datalog
# datatrieve
# dbase
# dc (computer program)
# digital command language
# dink smallwoody
# dibol
# dog (programming language)
# draco
# drakon
# dylan
# dynamo (programming language)
# data analysis expressions
# e
# ease
# pl/i
# easytrieve
# ec
# ecmascript
# edinburgh imp
# egl (programming language)
# eiffel
# elan
# elixir
# elm
# emacs lisp
# emerald
# epigram
# easy programming language
# eltron programming language
# erlang
# es (unix shell)
# escher
# executive systems problem oriented language
# esterel
# etoys
# euclid
# euler
# euphoria
# euslisp robot programming language
# cms exec
# exec 2
# executable uml
# ezhil
# f language
# f#
# f*
# factor
# fantom
# faust
# ffp (programming language)
# fjölnir
# fl
# flavors (programming language)
# flex (language)
# flow-matic
# focal
# focus
# foil (programming language)
# formac (programming language)
# formula language
# forth
# fortran
# fortress
# fp
# franz lisp
# f-script
# game maker language
# gamemonkey script
# gams
# gap computer algebra system
# g-code
# gdscript
# genie
# geometric description language
# george (programming language)
# glsl
# gnu e
# go
# go!
# game oriented assembly lisp
# gödel
# golo
# mad
# apps script
# gosu
# ibm 1620y
# gpss
# dxc technology
# grass (programming language)
# grasshopper
# groovy (programming language)
# hack
# haggis
# hal/s
# halide
# hamilton c shell
# harbour (software)
# hartmann pipeline
# haskell
# haxe
# hermes (programming language)
# high level assembly (hla)
# high level shader language
# hollywood
# templeos
# hop
# hopscotch (programming language)
# hope (programming language)
# hugo (programming language)
# hume (language)
# hypertalk
# io
# icon
# ibm basic assembly language
# ibm hascript
# ibm informix-4gl
# rpgreport program generator
# irineu
# idl (interactive data language)
# idris
# inform (programming language)
# j
# visual j#
# visual j++
# jade (programming language)
# jal (compiler)
# janus
# jass
# java
# javafx
# javascript
# job control language
# jean
# join java
# joss
# joule
# jovial
# joy
# jscript
# jscript .nety
# julia
# jythony
# k
# kaleidoscope (programming language)
# karel the robot
# intellicorp (software)y
# kixtart
# klerer-may system
# knowledge interchange format
# kojo (programming language)
# kotlin
# krc
# krl
# kuka robot language
# krypton
# korn shell
# kodu
# kivy
# labview
# ladder logic
# lansa (development environment)y
# lasso
# lava (programming language)
# lc-3
# legoscript
# little implementation language
# lilypond
# limbo
# limnor
# linc 4gl
# lingo (programming language)
# linq
# lis (programming language)
# language for instruction set architecture
# lisp
# lite-c
# lithe (programming language)
# little b
# ethereumy
# logo
# logtalk
# lotusscript
# lpc
# lse (programming language)
# linden scripting language
# livecode
# livescript
# lua
# lucid
# lustre (programming language)
# lyapas
# lynx (programming language)
# m2001
# m4
# m sharp (programming language)
# machine code
# magik (programming language)
# magma computer algebra system
# maude system
# máni
# maple
# mapper
# mark iv (software)
# mary
# microsoft macro assembler
# math-matic
# mathematica
# matlab
# maxima
# max
# autodesk 3ds maxy
# maya embedded language
# mdl
# mercury
# mesa[1]
# metafont
# mheg-5
# microassembler
# microscript (programming language)
# miis (programming language)
# milk (programming language)
# mimic
# mirah
# miranda
# miva script
# ml
# model 204
# modelica
# modula
# modula-2
# modula-3
# mohol programming languages
# moo
# mortran
# mouse (programming language)
# mpd (programming language)
# mathcad
# mirc scripting language
# mumps
# mupad
# mystic bbs
# netwide assembler
# napier88
# neko (programming language)
# nemerle
# nesl
# net.data
# netlogo
# netrexx
# newlisp
# newp
# newspeak
# newtonscript
# nial
# nice (programming language)
# nickle
# nim
# nord programming language
# not exactly c
# not quite c
# nullsoft scriptable install systemy
# nu
# nwscript
# nxt-g
# o:xml
# oak (programming language)
# oberon
# obj2
# object lisp
# objectlogo
# object rexx
# object pascal
# objective-c
# objective-j
# obliq
# ocaml
# occam
# occam-π
# gnu octave
# omnimark
# onyx (programming language)
# opa
# opal (programming language)
# opencl api
# openedge advanced business language (abl)
# open programming language (opl)
# openvera
# ops5
# optimj
# orc
# orca/modula-2
# oriel
# orwell
# oxygene
# oz
# p
# p4
# p′′
# parasail
# pari/gp
# pascal
# pascal script
# pcastl
# programming language for computable functions
# pearl (programming language)
# peoplecode
# perl
# perl data language (pdl)
# perl 6
# pharo
# php
# pico
# picolisp
# pict
# pig (programming tool)
# pike
# pilot
# pizza
# pl-11
# pl/0
# programming language for business
# pl/c
# pl/m
# pl/p
# pl/sql
# pl360
# planc
# plankalkül
# planner
# plex
# plexil
# plus
# pop-11
# pop-2
# postscript
# pov-ray
# powerhouse (programming language)
# appeon powerbuilder
# powershell
# polymorphic programming language
# processing
# processing.js
# prograph
# proiv
# prolog
# promal
# promela
# prose modeling language
# protel
# providex
# pro*c
# pure
# pure data
# python
# q
# q#
# قلب
# qtscript
# quakec
# quantum programming
# r
# r++
# racket
# rapid
# rapira
# ratfiv
# ratfor
# rc
# reason
# red
# core war
# refal
# rlab
# roop (programming language)
# rpl
# robot battle
# rtl/2
# ruby
# runescript
# rust
# s
# s2
# s3
# s-lang (programming language)
# s-plus
# sa-c (programming language)
# sabretalk
# sail (programming language)
# sam76
# sas system
# sasl
# sather
# sawzall (programming language)
# scala
# scheme
# scilab
# scratch
# script.net
# sed
# seed7
# self
# sensetalk
# sequencel
# setl
# superbase database
# signal (programming language)
# simple
# simscript
# simula
# simulink
# singularity project
# sisal
# slip (programming language)
# small
# smalltalk
# standard ml
# strongtalk
# snap! (byob[note 1])
# snobol
# snowball programming language
# secure operations language
# solidity
# sophaeros
# spark
# speakeasy
# speedcoding
# parallax propeller
# sp/k
# ibm 1401 symbolic programming system
# sql
# sqr
# squeak
# squirrel
# sr (programming language)
# s/sl programming language
# strand (programming language)
# stata
# stateflow
# subtext (programming language)
# supercollider
# supertalk
# swift
# swift (parallel scripting language)
# sympl
# systemverilog
# t
# tacl
# tacpol (programming language)
# tads
# transaction application language
# tcl
# tea
# text editor and correctory
# telcomp
# ubercode
# ucsd pascal/p-system
# umple
# unicon
# uniface
# unity (programming language)
# unix shell
# unrealscript
# vala
# verilog
# vhdl
# vim
# visual basic
# visual basic .nety
# visual dataflex
# visual dialogscript
# visual fortran
# visual foxpro
# visual j
# visual objects
# visual prolog
# vsxu
# watfiv (programming language)
# webassembly
# webdna
# whiley
# winbatch
# wolfram language
# wyvern (programming language)
# x++
# x10
# xbase
# xbase++
# xbl
# xc programming language
# xharbour
# xl
# xojo
# xotcl
# xod
# xpath
# xpl
# xpl0
# xquery
# xsb
# xsharp
# xsl transformations
# xtend
# yorick
# yql (programming language)
# yoix
# yahoo! user interface libraryy
# z notation
# zebra programming language
# zeno (programming language)
# zetalisp
# zopl
# z shell
# zpl
# z++
# wikipedia:citation neededy
# pl/pgsql
# sql/psm
# a♯
# newsqueak
# algol-like
# kornshell
# steelman language requirements
# ada programming language
# algol y
# ecmascript harmony
# actor-based concurrent language
# stos basic
# coopr
# mathematical notationy
# natural language programming
# javascript (programming language)
# autoit
# xslt
# category:c programming language familyy
# c99y
# dataparallel-c
# ansi cy
# *lisp (starlisp)
# typescript
# cω
# high performance fortrany
# cray mta
# cray xmt
# pl/1
# openmp
# hy
# lfe
# aimaco
# fact computer language
# yaml
# eulisp
# islisp
# moose (perl)
# skill
# subl
# lisp machine lisp
# maclisp
# interlisp
# oberon-2
# algol
# inform
# html(hypertext markup language)
# minid
# qore
# foxpro
# vp-info[1]
# windows powershelly
# common lisp object systemy
# redux
# vue.jsy
# agda
# alf (theorem prover)
# akka
# reia (programming language)
# simple theory of types
# croquet
# hypercard
# starlogo
# agentsheets
# concurrent euclid (programming language)
# turing
# fortran 95
# dafny (programming language)
# arith-matic
# basic-plus
# burroughs large systems
# pact i
# allegro common lisp
# bluespec, inc.y
# c++11y
# concepts (c++)y
# language integrated queryy
# isabelle theorem prover
# generics in javay
# omega
# purescript
# raku
# gofer (programming language)
# id (programming language)
# iswim
# ioke
# actor model middle history
# unicon programming language
# ibm rpg ii
# ibm 709/90 9pac
# fargo (programming language)
# numpyy
# gambas
# haxe (programming language)
# atscript
# qml
# cal (programming language)
# logic programmingy
# actor modely
# semi-automatic ground environmenty
# miranda programming language
# stackless python
# clips
# rebol
# information processing language (ipl)
# kturtle
# puredata
# interactive fictiony
# cedar (programming language)
# sasl programming language
# fortran 90
# zonnon
# algol-w
# modula-2+
# algol programming language
# lisp programming language
# muf (programming language)
# profile scripting language
# nineteen eighty-four: a novel y
# io programming language
# dylan programming language
# apl programming language
# active oberon
# rexx
# tom
# ats
# brainfucky
# oberon-2 (programming language)
# structured text
# awk (programming language)
# generic javay
# scala programming language
# superplan
# heinz rutishausery
# begriffsschrift
# portable document formaty
# interpress
# as/400 control language
# tk
# chef
# puppet (software)
# functional programmingy
# dataflow
# diagram
# kl0
# kl1
# business basic
# groovy
# xlispstat
# inferno
# reverse polish notationy
# scratchjr
# agentcubes
# ed
# setl2
# isetl
# list of object-oriented programming languagesy
# sac
# imp (programming language)
# sketchpad
# arpanety
# burroughs b5000
# cell (biology)y
# ml programming language
# java hotspot virtual machiney
# contextual query language
# sparql
# java persistence query language
# java object oriented queryingy
# n1ql
# unified modeling language
# icon programming language
# basic4ppc
# nsb/appstudio
# microsoft small basic
# opengl
# asm.js
# google native clienty
# symbolic manipulation program
# otcl
# xml schema (w3c)y
# xforms
# xpointer
# dsssl
# joins (concurrency library)
# polyphonic c sharp
# kawa
# clojure (programming language)
# hy (programming language)
# lelisp
# objvlisp
# oaklisp
# le lisp
# d language
# microsoft basic
# dartmouth basic
# tymshare super basic
# macsyma
# qt (framework)y
# xaml
# json
# dependent ml
# esoteric programming languagey
# hibernate (java)y
# qbasic
# t programming language
# openlisp
# list of basic dialectsy
# freebasic
# qb64
# quickbasic
# gw-basic
# msx basic
# ibm cassette basic
# ibm disk basic
# ibm basica
# vilnius basic

# %%
print(remove_ls)
# Out:
# [1320860, 92577, 840451, 390263, 34180789, 6761437, 41754003, 313216, 307436, 34739391, 208996, 7528520, 25432026, 277184, 945831, 607497, 3172, 1081482, 4895712, 191414, 50978621, 50462918, 5481447, 23708477, 13706337, 7955681, 381782, 10611640, 1637868, 28005, 14789, 23454753, 4086, 53891883, 29245633, 57131254, 10933, 733576, 22758, 292961, 4230, 1800920, 60675294, 20607025, 185449, 40659930, 53398, 48718969, 1774611]

# %%
remove = set(["ch c/c++ interpreter","templeos","javafx", "pig (programming tool)", "algol-like"])

for key in nodes:
    if nodes[key]['name'] in remove:
        remove_ls.append(key)

# %%
for key in nodes:
    if nodes[key]['name'] == "ethereum":
        print(key)
# Out:
# 41754003

# %%
print(remove_ls)
# Out:
# [1320860, 92577, 840451, 390263, 34180789, 6761437, 41754003, 313216, 307436, 34739391, 208996, 7528520, 25432026, 277184, 945831, 607497, 3172, 1081482, 4895712, 191414, 50978621, 50462918, 5481447, 23708477, 13706337, 7955681, 381782, 10611640, 1637868, 28005, 14789, 23454753, 4086, 53891883, 29245633, 57131254, 10933, 733576, 22758, 292961, 4230, 1800920, 60675294, 20607025, 185449, 40659930, 53398, 48718969, 1774611, 31643142, 46478098, 11117691, 57360209, 15986053]

# %%
remove_ls = [1320860, 92577, 840451, 390263, 34180789, 6761437, 313216, 307436, 34739391, 208996, 7528520, 25432026, 277184, 945831, 607497, 3172, 1081482, 4895712, 191414, 50978621, 50462918, 5481447, 23708477, 13706337, 7955681, 381782, 10611640, 1637868, 28005, 14789, 23454753, 4086, 53891883, 29245633, 57131254, 10933, 733576, 22758, 292961, 4230, 1800920, 60675294, 20607025, 185449, 40659930, 53398, 48718969, 1774611, 31643142, 46478098, 11117691, 57360209, 15986053]

# %%
for lid in remove_ls:
    nodes.pop(lid)

# %%
with open("Data/node_info.tsv", "w") as f:
    for key in nodes:
        d = nodes[key]
        f.write(f"{key}\t{d['name']}\t{d['year']}\t{d['paradigm']}\t{d['typing']}\n")

# %%
with open("edges.txt") as f:
    raw_lines = f.readlines()
    processed_lines = [tuple(map(int, line.strip().split(" "))) for line in raw_lines]

# %%
remove_set = set([1320860, 92577, 840451, 390263, 34180789, 6761437, 313216, 307436, 34739391, 208996, 7528520, 25432026, 277184, 945831, 607497, 3172, 1081482, 4895712, 191414, 50978621, 50462918, 5481447, 23708477, 13706337, 7955681, 381782, 10611640, 1637868, 28005, 14789, 23454753, 4086, 53891883, 29245633, 57131254, 10933, 733576, 22758, 292961, 4230, 1800920, 60675294, 20607025, 185449, 40659930, 53398, 48718969, 1774611, 31643142, 46478098, 11117691, 57360209, 15986053])

with open("Data/edges.txt", "w") as f:
    for i, j in processed_lines:
        if i not in remove_set and j not in remove_set:
            f.write(f"{i} {j}\n")

# %% [markdown]
# ### There were some entries with `|name| programming language`

# %%
with open("Data/node_info.tsv") as f:
    raw_lines = f.readlines()
    processed = [row.split('\t') for row in raw_lines]
    
    nodes = {}
    
    for line in processed:
        lang = {}
        lang_id = int(line[0])
        
        lang["name"] = line[1]
        lang["year"] = int(line[2])
        lang["paradigm"] = eval(line[3])
        lang["typing"] = eval(line[4])
        
        nodes[lang_id] = lang

# %%
suspect = []

for key in nodes:
    if "programming language" in nodes[key]['name']:
        suspect.append(key)

# %%
for lid in suspect:
    print(nodes[lid]['name'])
# Out:
# 1c:enterprise programming language
# acc (programming language)
# accent (programming language)
# actor (programming language)
# adenine (programming language)
# agora (programming language)
# apex (programming language)
# app inventor for android (programming language)
# apt (programming language)
# argus (programming language)
# bertrand (programming language)
# bliss (programming language)
# cayenne (programming language)
# cecil (programming language)
# céu (programming language)
# cg (programming language)
# clips (programming language)
# combined programming language
# cybil (programming language)
# d programming language
# dog (programming language)
# dynamo (programming language)
# egl (programming language)
# easy programming language
# eltron programming language
# euslisp robot programming language
# ffp (programming language)
# flavors (programming language)
# foil (programming language)
# formac (programming language)
# george (programming language)
# grass (programming language)
# groovy (programming language)
# hermes (programming language)
# hopscotch (programming language)
# hope (programming language)
# hugo (programming language)
# inform (programming language)
# jade (programming language)
# kaleidoscope (programming language)
# kojo (programming language)
# lava (programming language)
# lingo (programming language)
# lis (programming language)
# lithe (programming language)
# lse (programming language)
# lustre (programming language)
# lynx (programming language)
# m sharp (programming language)
# magik (programming language)
# microscript (programming language)
# miis (programming language)
# milk (programming language)
# mohol programming languages
# mouse (programming language)
# mpd (programming language)
# neko (programming language)
# nice (programming language)
# nord programming language
# oak (programming language)
# onyx (programming language)
# opal (programming language)
# open programming language (opl)
# programming language for computable functions
# pearl (programming language)
# programming language for business
# powerhouse (programming language)
# polymorphic programming language
# roop (programming language)
# s-lang (programming language)
# sa-c (programming language)
# sail (programming language)
# sawzall (programming language)
# signal (programming language)
# slip (programming language)
# snowball programming language
# sr (programming language)
# s/sl programming language
# strand (programming language)
# subtext (programming language)
# tacpol (programming language)
# unity (programming language)
# watfiv (programming language)
# wyvern (programming language)
# xc programming language
# yql (programming language)
# zebra programming language
# zeno (programming language)
# ada programming language
# javascript (programming language)
# reia (programming language)
# concurrent euclid (programming language)
# dafny (programming language)
# gofer (programming language)
# id (programming language)
# unicon programming language
# fargo (programming language)
# haxe (programming language)
# cal (programming language)
# miranda programming language
# cedar (programming language)
# sasl programming language
# algol programming language
# lisp programming language
# muf (programming language)
# io programming language
# dylan programming language
# apl programming language
# oberon-2 (programming language)
# awk (programming language)
# scala programming language
# imp (programming language)
# ml programming language
# icon programming language
# clojure (programming language)
# hy (programming language)
# t programming language

# %%
import re

# %%
pat = re.compile("(.+) \(?programming language\)?")
pat.match("acc (programming language)").group(1)
# Out:
# 'acc'

# %%
lang_names = [nodes[entry]['name'] for entry in nodes]

# %%
suspect
# Out:
# [60614939,
#  928669,
#  85065,
#  26849115,
#  11517646,
#  933477,
#  49183653,
#  43500036,
#  3673047,
#  27580389,
#  21119400,
#  24740516,
#  6528823,
#  527946,
#  52350190,
#  390212,
#  7755022,
#  31613960,
#  32669131,
#  243881,
#  37830261,
#  26064582,
#  1205107,
#  42016798,
#  8664562,
#  7416368,
#  934157,
#  1332640,
#  602746,
#  55755598,
#  36133392,
#  144766,
#  57417762,
#  24136948,
#  39338454,
#  933188,
#  1151504,
#  40650677,
#  5887624,
#  4400159,
#  52836480,
#  1982671,
#  493076,
#  12073324,
#  908572,
#  11730351,
#  2211835,
#  18530,
#  51974468,
#  2988758,
#  2232731,
#  3359079,
#  51603617,
#  948998,
#  6378343,
#  928466,
#  59627681,
#  294856,
#  37469066,
#  16840885,
#  3304684,
#  1936835,
#  832032,
#  31005079,
#  2603123,
#  350323,
#  25663569,
#  5005125,
#  931356,
#  356693,
#  8787221,
#  481275,
#  12640293,
#  32475185,
#  4449554,
#  30772911,
#  485875,
#  485828,
#  7837169,
#  2199610,
#  1719114,
#  3092830,
#  31410310,
#  43528524,
#  39153713,
#  26657733,
#  31495398,
#  928636,
#  25417347,
#  12572874,
#  20217814,
#  23153417,
#  57798059,
#  9019708,
#  15127771,
#  7239022,
#  6135484,
#  42302403,
#  1838572,
#  7238799,
#  9857086,
#  9123867,
#  261121,
#  7238785,
#  539194,
#  7071680,
#  7238578,
#  7238495,
#  50318793,
#  15703913,
#  7190667,
#  859608,
#  7389219,
#  7238710,
#  42702466,
#  45448513,
#  7239012]

# %%
pat = re.compile("(.+) \(programming language\)")

for lid in suspect:
    re_pat = pat.match(nodes[lid]['name'])
    if re_pat:
        short_name = re_pat.group(1)
        print(lid, short_name)
        nodes[lid]['name'] = short_name
# Out:
# 928669 acc
# 85065 accent
# 26849115 actor
# 11517646 adenine
# 933477 agora
# 49183653 apex
# 43500036 app inventor for android
# 3673047 apt
# 27580389 argus
# 21119400 bertrand
# 24740516 bliss
# 6528823 cayenne
# 527946 cecil
# 52350190 céu
# 390212 cg
# 7755022 clips
# 32669131 cybil
# 37830261 dog
# 26064582 dynamo
# 1205107 egl
# 934157 ffp
# 1332640 flavors
# 602746 foil
# 55755598 formac
# 36133392 george
# 144766 grass
# 57417762 groovy
# 24136948 hermes
# 39338454 hopscotch
# 933188 hope
# 1151504 hugo
# 40650677 inform
# 5887624 jade
# 4400159 kaleidoscope
# 52836480 kojo
# 1982671 lava
# 493076 lingo
# 12073324 lis
# 908572 lithe
# 11730351 lse
# 2211835 lustre
# 18530 lynx
# 51974468 m sharp
# 2988758 magik
# 2232731 microscript
# 3359079 miis
# 51603617 milk
# 6378343 mouse
# 928466 mpd
# 59627681 neko
# 294856 nice
# 16840885 oak
# 3304684 onyx
# 1936835 opal
# 2603123 pearl
# 25663569 powerhouse
# 931356 roop
# 356693 s-lang
# 8787221 sa-c
# 481275 sail
# 12640293 sawzall
# 32475185 signal
# 4449554 slip
# 485875 sr
# 7837169 strand
# 2199610 subtext
# 1719114 tacpol
# 3092830 unity
# 31410310 watfiv
# 43528524 wyvern
# 26657733 yql
# 928636 zeno
# 12572874 javascript
# 20217814 reia
# 23153417 concurrent euclid
# 57798059 dafny
# 9019708 gofer
# 15127771 id
# 6135484 fargo
# 42302403 haxe
# 1838572 cal
# 9857086 cedar
# 539194 muf
# 50318793 oberon-2
# 15703913 awk
# 859608 imp
# 42702466 clojure
# 45448513 hy

# %%
pat = re.compile("(.+) programming language")

for lid in suspect:
    re_pat = pat.match(nodes[lid]['name'])
    if re_pat:
        short_name = re_pat.group(1)
        if short_name in lang_names:
            print(lid, short_name)
            nodes[lid]['name'] = short_name
# Out:
# 25417347 ada
# 7239022 unicon
# 7238799 miranda
# 9123867 sasl
# 261121 algol
# 7238785 lisp
# 7071680 io
# 7238578 dylan
# 7238495 apl
# 7190667 scala
# 7389219 ml
# 7238710 icon
# 7239012 t

# %% [markdown]
# Repeat the joining thing from before

# %%
repeats = set()
names = set()

for key in nodes:
    name = nodes[key]["name"]
    if name in names:
        repeats.add(name)
    else:
        names.add(name)

for name in repeats:
    for key in nodes:
        if nodes[key]["name"] == name:
            print(nodes[key])
    print()
# Out:
# {'name': 'ada', 'year': 1980, 'paradigm': ['Multi-paradigm'], 'typing': ['static', 'strong', 'safe', 'nominative']}
# {'name': 'ada', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'apl', 'year': 1966, 'paradigm': ['Array', 'functional', 'structured', 'modular'], 'typing': ['dynamic']}
# {'name': 'apl', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'oberon-2', 'year': 1991, 'paradigm': ['imperative', 'structured', 'modular', 'object-oriented'], 'typing': ['strong', 'static']}
# {'name': 'oberon-2', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'io', 'year': 2002, 'paradigm': ['object-oriented', 'prototype-based'], 'typing': ['dynamic', 'strong']}
# {'name': 'io', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'icon', 'year': 1977, 'paradigm': ['multi-paradigm', 'structured'], 'typing': ['dynamic']}
# {'name': 'icon', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'groovy', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'groovy', 'year': 2003, 'paradigm': ['Object-oriented', 'imperative', 'scripting'], 'typing': ['dynamic', 'static', 'strong', 'duck']}
#
# {'name': 'ml', 'year': 1973, 'paradigm': ['Multi-paradigm', 'functional', 'imperative'], 'typing': ['inferred', 'static', 'strong']}
# {'name': 'ml', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'javascript', 'year': 1995, 'paradigm': ['Multi-paradigm', 'event-driven', '[1]', 'functional', 'imperative', 'object-oriented', 'prototype-based'], 'typing': ['dynamic', 'duck']}
# {'name': 'javascript', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'inform', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'inform', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'sasl', 'year': 1972, 'paradigm': ['functional'], 'typing': []}
# {'name': 'sasl', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'clips', 'year': 0, 'paradigm': [], 'typing': []}
# {'name': 'clips', 'year': 1985, 'paradigm': ['expert systems'], 'typing': []}
#
# {'name': 'scala', 'year': 2004, 'paradigm': ['Multi-paradigm', 'concurrent', 'functional', 'imperative', 'object-oriented'], 'typing': ['inferred', 'static', 'strong', 'structural']}
# {'name': 'scala', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'clojure', 'year': 2007, 'paradigm': ['multi-paradigm', 'agent-oriented', '[1]', 'concurrent', '[2]', '[3]', 'functional', '[4]', 'logic', '[5]', 'macro', '[6]', 'pipeline', '[7]'], 'typing': ['dynamic', 'strong']}
# {'name': 'clojure', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'miranda', 'year': 1985, 'paradigm': ['lazy', 'functional', 'declarative'], 'typing': ['strong', 'static']}
# {'name': 'miranda', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'hy', 'year': 2013, 'paradigm': ['Multi-paradigm', 'procedural', 'functional', 'object-oriented', 'meta', 'reflective', 'generic'], 'typing': []}
# {'name': 'hy', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'dylan', 'year': 1992, 'paradigm': ['multi-paradigm', 'functional', 'object-oriented'], 'typing': []}
# {'name': 'dylan', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'haxe', 'year': 2005, 'paradigm': ['Multi-paradigm'], 'typing': ['static', 'dynamic', 'nominal']}
# {'name': 'haxe', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 't', 'year': 1982, 'paradigm': ['Multi-paradigm', 'object-oriented', 'imperative', 'functional', 'meta'], 'typing': ['dynamic', 'strong']}
# {'name': 't', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'unicon', 'year': 0, 'paradigm': ['object-oriented', 'procedural'], 'typing': []}
# {'name': 'unicon', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'lisp', 'year': 1958, 'paradigm': ['Multi-paradigm', 'functional', 'procedural', 'reflective', 'meta'], 'typing': ['dynamic', 'strong']}
# {'name': 'lisp', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'awk', 'year': 1977, 'paradigm': ['Scripting', 'procedural', 'data-driven', '[1]'], 'typing': []}
# {'name': 'awk', 'year': 0, 'paradigm': [], 'typing': []}
#
# {'name': 'algol', 'year': 1958, 'paradigm': ['Procedural', 'imperative', 'structured'], 'typing': []}
# {'name': 'algol', 'year': 0, 'paradigm': [], 'typing': []}

# %%
double_entries = {}

for repeat in repeats:
    double_entries[repeat] = []

for key in nodes:
    lang = nodes[key]
    
    if lang["name"] in double_entries:
        entry = lang.copy()
        entry["id"] = key
        double_entries[lang["name"]].append(entry)

# %%
def merge_dicts(ds):
    acc = {'year': 0, 'paradigm':[], 'typing': []}
    
    d_scores = [0 for i in range(len(ds))]
    
    name = ds[0]['name']
    acc["name"] = name
    
    for i in range(len(ds)):
        if ds[i]["year"] != 0:
            acc["year"] = ds[i]['year']
            d_scores[i] += 1
        if len(ds[i]['paradigm']) != 0:
            acc["paradigm"] += ds[i]['paradigm']
            d_scores[i] += 1
        if len(ds[i]['typing']) != 0:
            acc["typing"] += ds[i]['typing']
            d_scores[i] += 1
    
    max_index = max(range(len(d_scores)), key=lambda x: d_scores[x])
    new_id = ds[max_index]['id']
    acc['id'] = new_id
    
    mapping = {}
    for d in ds:
        if d['id'] != new_id:
            mapping[d['id']] = new_id
    
    return acc, mapping

# %%
mapping = {}

for name in double_entries:
    acc, new_ids = merge_dicts(double_entries[name])
    nodes[acc['id']] = acc
    
    for key in new_ids:
        nodes.pop(key)
        mapping[key] = new_ids[key]

# %%
with open("Data/edges.txt") as f:
    raw_lines = f.readlines()
    processed_lines = [tuple(map(int, line.strip().split(" "))) for line in raw_lines]

# %%
mapped = [tuple(map(lambda x: mapping[x] if x in mapping else x, tup)) for tup in processed_lines]

with open("Data/edges.txt", "w") as f:
    for i, j in mapped:
        f.write(f"{i} {j}\n")

# %%
with open("Data/node_info.tsv", "w") as f:
    for key in nodes:
        d = nodes[key]
        f.write(f"{key}\t{d['name']}\t{d['year']}\t{d['paradigm']}\t{d['typing']}\n")

# %%
# reverse direction of edges because this is an citation network
with open("Data/edges.txt") as f:
    raw_lines = f.readlines()
    processed_lines = [tuple(map(int, line.strip().split(" "))) for line in raw_lines]

with open("Data/edges.txt", "w") as f:
    for i, j in processed_lines:
        f.write(f"{j} {i}\n")
